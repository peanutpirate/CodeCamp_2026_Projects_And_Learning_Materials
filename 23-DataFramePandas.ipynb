# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[ 0.37937844, -0.22599787, -0.88556911],
#        [ 0.85904625,  0.7751752 ,  0.92660336],
#        [-1.33907106, -0.69550843,  0.3405566 ],
#        [ 0.01080559, -1.47559502,  1.29015911]])

# %%
dataFrame = pd.DataFrame(data)

# %%
dataFrame[0] # column olarak getiriyor row olarak getirmiyor
# Out:
# 0    0.379378
# 1    0.859046
# 2   -1.339071
# 3    0.010806
# Name: 0, dtype: float64

# %%
dataFrame # serilerin iki boyutlu hali
# Out:
#           0         1         2
# 0  0.379378 -0.225998 -0.885569
# 1  0.859046  0.775175  0.926603
# 2 -1.339071 -0.695508  0.340557
# 3  0.010806 -1.475595  1.290159

# %%
yeniDataFrame = pd.DataFrame(data,index=["Atil","Zeynep","Atlas","Mehmet"],columns = ["Maas","Yas","Calisma Verileri"])

# %%
yeniDataFrame["Yas"]
# Out:
# Atil     -0.225998
# Zeynep    0.775175
# Atlas    -0.695508
# Mehmet   -1.475595
# Name: Yas, dtype: float64

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Verileri
# Atil    0.379378 -0.225998         -0.885569
# Zeynep  0.859046  0.775175          0.926603
# Atlas  -1.339071 -0.695508          0.340557
# Mehmet  0.010806 -1.475595          1.290159

# %%
yeniDataFrame[["Maas","Yas"]]
# Out:
#             Maas       Yas
# Atil    0.379378 -0.225998
# Zeynep  0.859046  0.775175
# Atlas  -1.339071 -0.695508
# Mehmet  0.010806 -1.475595

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Verileri
# Atil    0.379378 -0.225998         -0.885569
# Zeynep  0.859046  0.775175          0.926603
# Atlas  -1.339071 -0.695508          0.340557
# Mehmet  0.010806 -1.475595          1.290159

# %%
yeniDataFrame.loc["Atil"] #rowlarda loc yazıyoruz çünkü öncelikle column arıyor
# Out:
# Maas                0.379378
# Yas                -0.225998
# Calisma Verileri   -0.885569
# Name: Atil, dtype: float64

# %%
yeniDataFrame.iloc[1] # index sayısı
# Out:
# Maas                0.859046
# Yas                 0.775175
# Calisma Verileri    0.926603
# Name: Zeynep, dtype: float64

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Verileri
# Atil    0.379378 -0.225998         -0.885569
# Zeynep  0.859046  0.775175          0.926603
# Atlas  -1.339071 -0.695508          0.340557
# Mehmet  0.010806 -1.475595          1.290159

# %%
#yeni kolon eklemek istiyoruz. nasıl yapıcaz?

# %%
yeniDataFrame["Emeklilik Yasi"] = yeniDataFrame["Yas"] + yeniDataFrame["Yas"]

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Verileri  Emeklilik Yasi
# Atil    0.379378 -0.225998         -0.885569       -0.451996
# Zeynep  0.859046  0.775175          0.926603        1.550350
# Atlas  -1.339071 -0.695508          0.340557       -1.391017
# Mehmet  0.010806 -1.475595          1.290159       -2.951190

# %%
yeniDataFrame.drop("Emeklilik Yasi",axis = 1)
# Out:
#             Maas       Yas  Calisma Verileri
# Atil    0.379378 -0.225998         -0.885569
# Zeynep  0.859046  0.775175          0.926603
# Atlas  -1.339071 -0.695508          0.340557
# Mehmet  0.010806 -1.475595          1.290159

# %%
yeniDataFrame.drop("Mehmet")
# Out:
#             Maas       Yas  Calisma Verileri  Emeklilik Yasi
# Atil    0.379378 -0.225998         -0.885569       -0.451996
# Zeynep  0.859046  0.775175          0.926603        1.550350
# Atlas  -1.339071 -0.695508          0.340557       -1.391017

# %%
yeniDataFrame.drop("Emeklilik Yasi", axis = 1, inplace=True)

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Verileri
# Atil    0.379378 -0.225998         -0.885569
# Zeynep  0.859046  0.775175          0.926603
# Atlas  -1.339071 -0.695508          0.340557
# Mehmet  0.010806 -1.475595          1.290159

# %%
yeniDataFrame.loc["Atil"]["Yas"]
# Out:
# np.float64(-0.2259978692596928)

# %%
yeniDataFrame.loc["Atil","Yas"]
# Out:
# np.float64(-0.2259978692596928)

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Verileri
# Atil    0.379378 -0.225998         -0.885569
# Zeynep  0.859046  0.775175          0.926603
# Atlas  -1.339071 -0.695508          0.340557
# Mehmet  0.010806 -1.475595          1.290159

# %%
booleanFrame = yeniDataFrame < 0

# %%
booleanFrame
# Out:
#          Maas    Yas  Calisma Verileri
# Atil    False   True              True
# Zeynep  False  False             False
# Atlas    True   True             False
# Mehmet  False   True             False

# %%
yeniDataFrame[booleanFrame]
# Out:
#             Maas       Yas  Calisma Verileri
# Atil         NaN -0.225998         -0.885569
# Zeynep       NaN       NaN               NaN
# Atlas  -1.339071 -0.695508               NaN
# Mehmet       NaN -1.475595               NaN

# %%
yeniDataFrame[yeniDataFrame["Yas"] > 0]
# Out:
#             Maas       Yas  Calisma Verileri
# Zeynep  0.859046  0.775175          0.926603

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Verileri
# Atil    0.379378 -0.225998         -0.885569
# Zeynep  0.859046  0.775175          0.926603
# Atlas  -1.339071 -0.695508          0.340557
# Mehmet  0.010806 -1.475595          1.290159

# %%
yeniDataFrame.reset_index()
# Out:
#     index      Maas       Yas  Calisma Verileri
# 0    Atil  0.379378 -0.225998         -0.885569
# 1  Zeynep  0.859046  0.775175          0.926603
# 2   Atlas -1.339071 -0.695508          0.340557
# 3  Mehmet  0.010806 -1.475595          1.290159

# %%
yeniIndeksListesi = ["Ati","Zey","Atl","Meh"]

# %%
yeniDataFrame.set_index["Yeni Indeks",inplace = True]
# Out:
#   Cell In[63], line 1
#     yeniDataFrame.set_index["Yeni Indeks",inplace = True]
#                                           ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
ilkIndeksler = ["Simpson","Simpson","Simpson","SouthPark","SouthPark","SouthPark"]

# %%
IcIndeksler = ["Homer","Bart","Marge","Cartman","Kenny","Kyle"]

# %%
birlesmisIndeks = list(zip(ilkIndeksler,IcIndeksler))

# %%
birlesmisIndex = pd.MultiIndex.from_tuples(birlesmisIndeks)

# %%
birlesmisIndex
# Out:
# MultiIndex([(  'Simpson',   'Homer'),
#             (  'Simpson',    'Bart'),
#             (  'Simpson',   'Marge'),
#             ('SouthPark', 'Cartman'),
#             ('SouthPark',   'Kenny'),
#             ('SouthPark',    'Kyle')],
#            )

# %%
benimCizgiFilmListem = [[40,"A"],[10,"B"],[30,"C"],[9,"D"],[10,"E"],[11,"F"]]

# %%
cizgiFilmNumpyDizisi = np.array(benimCizgiFilmListem)

# %%
cizgiFilmDataFrame = pd.DataFrame(cizgiFilmNumpyDizsi, index=birlesmisIndeks,columns=["Yas","Meslek"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 cizgiFilmDataFrame = pd.DataFrame(cizgiFilmNumpyDizsi, index=birlesmisIndeks,columns=["Yas","Meslek"])
#
# NameError: name 'cizgiFilmNumpyDizsi' is not defined
