# %%
3 > 1
# Out:
# True

# %%
# verilen boolean değerine göre işlemler yapabiliriz.

# %%
if 3 > 4: 
    print("atıl samancıoğlu") #Python boşluk bıra
    print("if koşulu sağlandı")
print("if koşulunun dışına çıktık") #işlemin sonucu True ise kodlar çalıştırılacak)
# Out:
# if koşulunun dışına çıktık

# %%
# eğer 3 > 4 ten büyüktür deseydik yazdırmıycak da kod bloğu bolşuklarla belirtilir.

# %%
x = 5

# %%
y = 4

# %%
if x > y:
    print("x, y'den daha büyükmüş")
elif
# Out:
# x, y'den daha büyükmüş

# %%
# koşu tutarsa veri tabanına kaydet ya da şu koşul tutarsa kaydet. kullanıcı 18 yaşından büyükse siteye girişe izin ver. Ya da verme.

# %%
# else if aslında eğer öyle değilse anlamına gelir
# elif olarak gösterilir

# %%
if x > y:
    print("x, y'den daha büyükmüş")
elif y > x:
    print("y, x'den daha büyükmüş")
else:
    print("y ve x birbirine eşitmiş")
# Out:
# x, y'den daha büyükmüş

# %%
# else koşulların hiç biri tutmadığında kullanılır. Else den sonra : üst üste 
# kullanilir ve if koşullarından sonra : kullanilir.

# %%
# kullanıcımız süper kahramanı verdiğinde birşeyler yazdıralım

# %%
benimKahramanim = input("Super Kahraman seçiniz: ")
# Out:
# Super Kahraman seçiniz:  Batman

# %%
if benimKahramanim == "Batman":
    print("Batman'i seçtiniz tebrikler")
elif benimKahramanim == "Superman":
    print("Keşke Batman'i seçseydiniz")
elif benimKahramanim == "Ironman":
    print("Iron man kimdir?")
else:
    print("Bu kim gerçekten bilmiyoruz")
# Out:
# Batman'i seçtiniz tebrikler

# %%
a = 10
b = 20
c = 20

# %%
if a > b and b > c: 
    print("a, b'den büyük Ve b de c'den büyük")
elif a < b and b < c: 
    print("a, b'den küçük ve b de c'den küçük")
else:
    print("bu koşullar tutmadı")
# Out:
# bu koşullar tutmadı

# %%
m = 10
k = 4
l = 5

# %%
if m > k or k > 1:
    print("bu çalıştırılacak mı?")
# Out:
# bu çalıştırılacak mı?

# %%
# mesela oyun yazıyoruz karakterin canı kaldı mı kalmadı mı?
karakterCanli = True

# %%
if karakterCanli == True:
    print("oyun karakteriniz yaşıyor")
else:
    print("oyun karakteriniz yaşamıyor")
# Out:
# oyun karakteriniz yaşıyor

# %%
if karakterCanli:
    print("oyun karakteri yaşıyor")
else:
    print("oyun karakteri yaşamıyor")
# Out:
# oyun karakteri yaşıyor

# %%
if not karakterCanli:
    print("karakter canlı değil")

# %%
benimString = "Atil Samancioğlu"

# %%
if benimString == "atil samancioğlu":
    print("eşitmiş")
else:
    print("eşit değilmiş")
# Out:
# eşit değilmiş

# %%
if "Samancioğlu" in benimString: #arada boşluk varmı diye bakmıyor bu var mı bakıyor.
    print("varmış")
else:
    print("yokmuş")
# Out:
# varmış

# %%
benimListem = [10,20,30,40,50]

# %%
if 60 in benimListem:
    print("evet var")

# %%
benimSozluk = {"muz" : 100, "elma" : 150, "karpuz": 500}

# %%
benimSozluk.keys()
# Out:
# dict_keys(['muz', 'elma', 'karpuz'])

# %%
if "muz" in benimSozluk.keys():
    print("varmış")
# Out:
# varmış

# %%
if 250 in benimSozluk.values():
    print("evet")
