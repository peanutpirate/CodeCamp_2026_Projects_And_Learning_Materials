# %%
benimListem = [1,2,3,1,2,3]

# %%
benimListem
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
# Yukarıdaki listenin aksine set bir elemanı sadece bir defa barındırır

# %%
# bir veri setini başka bir şeye çevirme casting denir

# %%
benimListeSetim = set(benimListem)

# %%
type(benimListem)
# Out:
# list

# %%
type(benimListeSetim)
# Out:
# set

# %%
benimListeSetim
# Out:
# {1, 2, 3}

# %%
# listeyi sete çevirirsek içinde birde fazla yazılmış veriler temizlenir.

# %%
# Örneğin bir eticaret sitesinin verilerini inceliyorsunuz. Hangi illere yapılacağını bulacaksınız. Bu listeyi sete alırsanız sadece birer tane il kalacağı için kaç tane eleman olduğunu sayarsanız totalde kaç şehire sevkiyat yapıldığını bulabilirsiniz.

# %%
benimSet = {"a","b","c","a"}

# %%
type(benimSet)
# Out:
# set

# %%
benimSet
# Out:
# {'a', 'b', 'c'}

# %%
# bir eleman bir defa tanımlanır çünkü bu bir set

# %%
# süslü parantezle tanımlanır {} dictionary gibi

# %%
bosListe = []

# %%
type(bosListe)
# Out:
# list

# %%
bosListe
# Out:
# []

# %%
bosListe.append(1) # listenin içine ekleme yapılır

# %%
bosListe
# Out:
# [1]

# %%
bosSet = {}

# %%
type(bosSet)
# Out:
# dict

# %%
bosSozluk = {}

# %%
type(bosSozluk)
# Out:
# dict

# %%
bosSozluk["anahtarKelime"] = 10

# %%
bosSozluk
# Out:
# {'anahtarKelime': 10}

# %%
benimBosSetim = set()

# %%
benimBosSetim
# Out:
# set()

# %%
benimBosSetim.add(10)

# %%
benimBosSetim.add(10)

# %%
benimBosSetim.add(20)

# %%
benimBosSetim
# Out:
# {10, 20}

# %%
benimBosListem = list()

# %%
benimBosListem
# Out:
# []

# %%
benimBosListem.append(10)

# %%
benimBosListem
# Out:
# [10]

# %%
benimBosSozlugum = dict()

# %%
benimBosSozlugum["key"] = 3234
