# %%
import numpy as np
import matplotlib.pyplot as matplot

# %%
maasListesi = np.random.normal(400,500,1000)

# %%
np.mean(maasListesi)
# Out:
# np.float64(401.0954423100804)

# %%
matplot.hist(maasListesi,50)
matplot.show()

# %%
# Modüller tek başına python dosyalarıdır. 
# paketler geniş kapsamlısıdır.
