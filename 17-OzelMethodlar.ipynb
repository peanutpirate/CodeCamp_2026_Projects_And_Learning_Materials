# %%
class Meyve():

    def __init__(self,isim,kalori):
        self.isim = isim
        self.kalori = kalori

    def __str__(self):
        return f"{self.isim} şu kadar kaloriye sahiptir: {self.kalori}"

    def __len__(self):
        return self.kalori

# %%
muz = Meyve("Muz",150)

# %%
muz.kalori
# Out:
# 150

# %%
print(muz)
# Out:
# Muz şu kadar kaloriye sahiptir: 150

# %%
benimListem = [1,2,3,"a",4.5]

# %%
print(benimListem)
# Out:
# [1, 2, 3, 'a', 4.5]

# %%
len(benimListem) # içinde kaç tane eleman var
# Out:
# 5

# %%
len(muz)
# Out:
# 150

# %%
elma = Meyve("Elma", 200)

# %%
print(elma)
# Out:
# Elma şu kadar kaloriye sahiptir: 200

# %%
# special methods diye aratıp dökümantasyonları oku
