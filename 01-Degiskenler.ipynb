# %%
5*4
# Out:
# 20

# %%
1000 + 2500
# Out:
# 3500

# %% [markdown]
# Python Öğreniyorum

# %%
##Python Öğreniyorum

# %%
## Python Öğreniyorum

# %% [markdown]
# ## Variables (Değişkenler)

# %%
x = 6

# %%
y = 4

# %%
x * y
# Out:
# 24

# %%
y * 10
# Out:
# 40

# %% [markdown]
# ## Integer (Tam Sayı) & Float (Kesirli Sayılar)

# %%
benimDegiskenim = 10
benimDigerDegiskenim = 20

# %%
benimDegiskenim + benimDigerDegiskenim
# Out:
# 30

# %%
type(benimDegiskenim)
# Out:
# int

# %%
sonuc = benimDigerDegiskenim / benimDegiskenim

# %%
sonuc
# Out:
# 2.0

# %%
type(sonuc) # Tam sayılar bölünse bile kesirli sayı olarak cevap veriyor yani FLOAT
# Out:
# float

# %%
a = 3
b = 2

# %%
a / b
# Out:
# 1.5

# %%
pi = 3.14

# %%
type(pi)
# Out:
# float

# %%
a = 5

# %%
type(a)
# Out:
# int

# %%
a / pi
# Out:
# 1.592356687898089

# %%
a = 5
b = 4

# %%
sonuc = a + b

# %%
type(sonuc)
# Out:
# int

# %%
sonuc = a * b

# %%
type(sonuc)
# Out:
# int

# %% [markdown]
# ## Matematiksel İşlemler

# %%
x = 5
y = 3

# %%
x * y * 10
# Out:
# 150

# %%
x * x * x * x
# Out:
# 625

# %%
x ** 4 # üzeri iki yıldızla gösterilir
# Out:
# 625

# %%
# Remainder - Kalanını Bulmak
10 % 2
# Out:
# 0

# %%
11 % 3
# Out:
# 2

# %%
kullanicininYasi = 10

# %%
## camelCase snake_case

# %%
kullanicininYasi * 5 / 3
# Out:
# 16.666666666666668

# %%
kullanicininYasi = input("Yaşınızı Giriniz: ")
# Out:
# Yaşınızı Giriniz:  40

# %%
kullanicininYasi
# Out:
# '40'

# %%
type(kullanicininYasi)
# Out:
# str

# %%
kullanicininYasi * 5 # str (String) yani metin olarak gördüğü için yan yana yazacak
# Out:
# '4040404040'

# %% [markdown]
# ## String

# %%
"merhaba dünya"
# Out:
# 'merhaba dünya'

# %%
x = "merhaba dünya"

# %%
x = 10

# %%
x = 20.5

# %%
x = "hello"

# %%
type(x)
# Out:
# str

# %%
y = 'yeni string'

# %%
type(y)
# Out:
# str

# %%
"Atıl'ın Yeri"
# Out:
# "Atıl'ın Yeri"

# %%
a = 5

# %%
y.capitalize()
# Out:
# 'Yeni string'

# %%
y.split()
# Out:
# ['yeni', 'string']

# %%
benimString = "Atıl Samancıoğlu"

# %%
benimString * 4
# Out:
# 'Atıl SamancıoğluAtıl SamancıoğluAtıl SamancıoğluAtıl Samancıoğlu'

# %%
benimInput = input("Yaşınızı Giriniz: ")
# Out:
# Yaşınızı Giriniz:  33

# %%
type(benimInput)
# Out:
# str

# %%
benimIntInput = int(benimInput)

# %%
benimIntInput / 3 * 5
# Out:
# 55.0

# %%
k = "Egmen"

# %%
len(k)
# Out:
# 5

# %%
print("merhaba \npython") # \n bir alt satıra geçer
# Out:
# merhaba
# python

# %%
isimString = "Ipek Egmen"

# %%
isimString
# Out:
# 'Ipek Egmen'

# %% [markdown]
# ## Index

# %%
# her stringin içinde harflere atanmış bir index vardır ve ilk harf 0 sıfırla başlar

# %%
isimString[0]
# Out:
# 'I'

# %%
isimString[4]
# Out:
# ' '

# %%
isimString[-1] # - yapınca sondan bir harf alır ama -2 yazarsanız 1 yazar :)
# Out:
# 'n'

# %%
isimString[0] + isimString[-1]
# Out:
# 'In'

# %%
yeniString = "0123456789"

# %%
yeniString[2:]
# Out:
# '23456789'

# %%
harfString = "abcdefgh"

# %%
harfString[3:]
# Out:
# 'defgh'

# %%
harfString[:3] # ilk 3 elemanı aldı)
# Out:
# 'abc'

# %% [markdown]
# ## Slicing

# %%
gelenVeri = "AhmetinYasi65"

# %%
gelenVeri[-2:] # Sadece yaşı istedik. Sondan 2 indexi aldı.
# Out:
# '65'

# %%
gelenVeri[2:4] # başlagınç indexi:durdurma indexi /Starting index Stoping Index
# Out:
# 'me'

# %%
# Step Size (atlama indexi)

# %%
gelenVeri[::3]
# Out:
# 'Aens5'

# %%
gelenVeri[::-1] # Tersten yazma işlemi
# Out:
# '56isaYnitemhA'

# %%
benimIsmim = "ipek"

# %%
benimIsmim.capitalize()
# Out:
# 'Ipek'

# %%
benimIsmim
# Out:
# 'ipek'

# %%
benimYeniIsmim = benimIsmim.capitalize()

# %%
benimYeniIsmim
# Out:
# 'Ipek'

# %%
benimTamIsmim = "Ipek Egmen Test"

# %%
listeler = benimTamIsmim.split()

# %%
# köşeli parantezler listedir. İçerisinde birden fazla veri olan bir yapı

# %%
benimTamIsmim.upper()
# Out:
# 'IPEK EGMEN TEST'

# %%
benimIsmim
# Out:
# 'ipek'

# %%
benimIsmim * 10
# Out:
# 'ipekipekipekipekipekipekipekipekipekipek'

# %%
benimIsmim + " dır"
# Out:
# 'ipek dır'

# %%
benimSoyismim = "egmen"

# %%
benimIsmim + benimSoyismim
# Out:
# 'ipekegmen'

# %%
benimIsmim + " " + benimSoyismim
# Out:
# 'ipek egmen'

# %%
j = "5"
k = "10"
j + k
# Out:
# '510'
