# %%
benimString = "Ipek Egmen"

# %%
benimString[0]
# Out:
# 'I'

# %%
# immutability & mutable (Değişebilir/Değişemezlik)

# %%
# benimString[0] = "B" # değişmezlik var immutability

# %%
benimListem = [10,20,30,40]

# %%
type(benimListem)
# Out:
# list

# %%
benimNumaram = 10
benimDigerNumaram = 20

# %%
benimNumaraListem = [benimNumaram,benimDigerNumaram]

# %%
benimListem[3]
# Out:
# 40

# %%
benimListem[0]
# Out:
# 10

# %%
benimListem[0] = 100

# %%
benimListem
# Out:
# [100, 20, 30, 40]

# %%
benimListem.append(50) #append eklemek demek

# %%
benimListem
# Out:
# [100, 20, 30, 40, 50, 50]

# %%
benimListem.pop() # son elemanı atmaya yarıyor
# Out:
# 50

# %%
benimListem
# Out:
# [100, 20, 30, 40, 50]

# %%
benimListem.remove(40) # içindeki elemanı çıkartmaya çalışıyor

# %%
benimListem
# Out:
# [100, 20, 30, 50]

# %%
# benimListem.remove(5) # Listenin içinde olmayan birşey çıkarılamaz

# %%
benimListem.count(20) # bir listenin içinde kaç tane var bir elemanda
# Out:
# 1

# %%
benimListem.append(20)

# %%
benimListem
# Out:
# [100, 20, 30, 50, 20]

# %%
benimListem.count(20)
# Out:
# 2

# %%
benimStringListem = ["atıl","ahmet","zeynep"]

# %%
benimDigerListem = ["mehmet", "mahmut", "atlas"]

# %%
benimToplamaListem = benimStringListem + benimDigerListem

# %%
benimToplamaListem
# Out:
# ['atıl', 'ahmet', 'zeynep', 'mehmet', 'mahmut', 'atlas']

# %%
benimStringListem * 5 # çarpmaya izin veriyor ama bölmeye izin vermiyor çıkarmaya izin vermiyor
# Out:
# ['atıl',
#  'ahmet',
#  'zeynep',
#  'atıl',
#  'ahmet',
#  'zeynep',
#  'atıl',
#  'ahmet',
#  'zeynep',
#  'atıl',
#  'ahmet',
#  'zeynep',
#  'atıl',
#  'ahmet',
#  'zeynep']

# %%
benimToplamaListem
# Out:
# ['atıl', 'ahmet', 'zeynep', 'mehmet', 'mahmut', 'atlas']

# %%
benimToplamaListem.reverse()

# %%
benimToplamaListem
# Out:
# ['atlas', 'mahmut', 'mehmet', 'zeynep', 'ahmet', 'atıl']

# %%
karisikListe = [1,2,3.5,"atıl",9]

# %%
type(karisikListe)
# Out:
# list

# %%
sonucum = karisikListe[3]
karisikListe[3]
# Out:
# 'atıl'

# %%
type(sonucum)
# Out:
# str

# %%
nestedList = [1,5,"atıl",4,[6,"z"]] # nested biribiri içine geçmiş yuvalanmış katmanlı demek

# %%
zDegiskenimiz = nestedList[4][1]

# %%
zDegiskenimiz
# Out:
# 'z'

# %%
karmasikListe = [[1,2,3,["a","b"],50],40,20,["z",5.5],[3,["a"]]]

# %%
bDegiskenimiz = karmasikListe[0][3][1]

# %%
bDegiskenimiz
# Out:
# 'b'

# %%
nestedList
# Out:
# [1, 5, 'atıl', 4, [6, 'z']]

# %%
nestedList[:2]
# Out:
# [1, 5]

# %%
type(nestedList[2])
# Out:
# str

# %%
# tek kolesiyonumuz listeler değil :P
