# %%
def toplama(numara1, numara2):
    return numara1 + numara2

# %%
x = int(input("ilk numarayı giriniz: "))
y = int(input("ikinci numrayı giriniz:" ))
toplama(x,y)
# Out:
# ilk numarayı giriniz:  1
# ikinci numrayı giriniz: 2
# 3

# %%
# try & except & else & finally

# %%
while True:
    try:
        benimInt = int(input("Numaranızı giriniz: "))
    except:
        print("Lütfen gerçekten numara giriniz")
        continue
    else:
        print("Teşekkürler")
        break
    finally:
        print("finally çağrıldı")
# Out:
# Numaranızı giriniz:  2
# Teşekkürler
# finally çağrıldı
