# %%
benimBoolean = True

# %%
# sadece true ya da false değerini alır
# yani doğru ya da yanlış

# %%
type(benimBoolean)
# Out:
# bool

# %%
benimBoolean = False

# %%
# Değişken olarak veriyi tutmak isteyebilirsiniz. Mesela bir oyun yazıyorsunuz. Karater canlı mı değil mi? Canlı = True Değil = False

# %%
# asıl yapacağınız kontroller bu string bu stringe eşitmi ya da büyükmü

# %%
# bir şirketteki maaşları analiz ediyoruz. Ortalamadan büyük mü bir kişinin maaşı? İki rakamı kontrol ederken 10 < 5

# %%
10 > 5
# Out:
# True

# %%
10 < 5
# Out:
# False

# %%
listem = [5000,10000,3000,1000,2000,4000]

# %%
len
# Out:
# <function len(obj, /)>

# %%
# len length liste uzunluğunu verir.

# %%
len(listem)
# Out:
# 6

# %%
sum(listem)
# Out:
# 25000

# %%
ortalama = sum(listem) / len(listem)

# %%
ortalama
# Out:
# 4166.666666666667

# %%
listem[3] > ortalama
# Out:
# False

# %%
# türkiyede bir araştırma yapılmış ortalama insanların maaşını bulmuş

# %%
kullaniciMaas = input("maaş bilgisini giriniz: ")
# Out:
# maaş bilgisini giriniz:  6000

# %%
type(kullaniciMaas)
# Out:
# str

# %%
kullaniciMaasInt = int(kullaniciMaas)

# %%
kullaniciMaasInt > ortalama
# Out:
# True

# %%
x = 10
y = 8

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
x <= y
# Out:
# False

# %%
x >= y
# Out:
# True

# %%
x = 10

# %%
y = 8

# %%
x == y
# Out:
# False

# %%
# x == eşit mi değil mi kontrol eder iki eşitlik

# %%
x != y
# Out:
# True

# %%
# != eşit değildir kontrol eder

# %%
3 > 1 and 3 > 2
# Out:
# True

# %%
# and dediğimizde sol tarafında sağ tarafında doğru olması gerekir

# %%
1 > 3 and 3 > 2
# Out:
# False

# %%
1 < 3 or 3 > 2
# Out:
# True

# %%
# or dedğimde sol ya da sağ taraftan doğru olması True olması için yeterli

# %%
not 5 == 5
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
# not birşeyi olumsuz yapar

# %%
not 5 == 4
# Out:
# True
