# %%
# tuplelerde immutability değişmezlik vardır

# %%
benimListem = [1,2,"a",4.5]

# %%
benimListem[0]
# Out:
# 1

# %%
benimListem[0] = 100

# %%
benimListem
# Out:
# [100, 2, 'a', 4.5]

# %%
benimTuple = (1,2,"a",4.5)

# %%
benimTuple
# Out:
# (1, 2, 'a', 4.5)

# %%
benimTuple[0]
# Out:
# 1

# %%
# benimTuple[2] = "b" sonradan değiştirelemez

# %%
# bizim yazdığımız verileri kullanacak değiştiriceler olursa değiştirilmemesini isteyebiliriz. Tupleın kullanılma alanlarından bir tanesidir.

# %%
# Kütüphaneler çoğu zaman tuple döndürür bize geriye. 
# kullanıcının maaşları ile ilgili bir işlem yapılması gerekiyor ortalaması alınacak. sonra sapması hesaplanacak. 1500 kişinin maaşı için. Kütüphane veriyi veriyoruz. Liste halinde geriye tüm sapmaları veriyor. Tuple halinde verir ki sanuçları yani sapmaları değiştirmeyelim.

# %%
benimTuple.count("a")
# Out:
# 1

# %%
benimTuple.index(4.5)
# Out:
# 3

# %%
# tuple ın kullanbilir fonksiyonları
# .count elemandan kaç tane var. 
# .index hangi sırada
